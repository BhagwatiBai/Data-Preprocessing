# %%
import numpy as np
import pandas as pd

# %%
distance_list = [50,100,65,150]
time_taken_list = [10,20,14,30]

# %%
# creating a numpy array from lists

distance_ndarray = np.array(distance_list)
time_taken_ndarray = np.array(time_taken_list)

# %%
print(distance_ndarray)
print(time_taken_ndarray)
# Out:
# [ 50 100  65 150]
# [10 20 14 30]

# %%
speed = distance_ndarray/time_taken_ndarray

# %%
speed
# Out:
# array([5.        , 5.        , 4.64285714, 5.        ])

# %%
uber_df = pd.read_csv('UberDrives2016.csv')
uber_df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
uber_df.size
# Out:
# 8092

# %%
uber_df.shape
# Out:
# (1156, 7)

# %%
uber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
uber_df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
count_nan = uber_df.isnull().sum()
print(count_nan[count_nan > 0])
# Out:
# END_DATE*      1
# CATEGORY*      1
# START*         1
# STOP*          1
# PURPOSE*     503
# dtype: int64

# %%
type(uber_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Basic DataFrame Operations

# %%
uber_df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber_df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
uber_df.head(n=12)
# Out:
#         START_DATE*        END_DATE* CATEGORY*           START*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5    1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6    1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7    1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9   1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
# 10  1/10/2016 15:08  1/10/2016 15:51  Business         New York
# 11  1/10/2016 18:18  1/10/2016 18:53  Business         Elmhurst
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# ...

# %%
uber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
uber_df.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Columns: 7 entries, START_DATE* to PURPOSE*
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
uber_df.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
uber_df['MILES*'].describe()
# Out:
# count     1156.000000
# mean        21.115398
# std        359.299007
# min          0.500000
# 25%          2.900000
# 50%          6.000000
# 75%         10.400000
# max      12204.700000
# Name: MILES*, dtype: float64

# %% [markdown]
# # Attributes of DataFrame

# %%
uber_df.shape
# Out:
# (1156, 7)

# %%
uber_df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
uber_df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
uber_df.axes
# Out:
# [RangeIndex(start=0, stop=1156, step=1),
#  Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#         'PURPOSE*'],
#        dtype='object')]

# %%
uber_df.ndim
# Out:
# 2

# %%
uber_df.size # product of rows * columns
# Out:
# 8092

# %%
uber_df.T
# Out:
#                        0              1                2               3     \
# START_DATE*  1/1/2016 21:11  1/2/2016 1:25   1/2/2016 20:25  1/5/2016 17:31
# END_DATE*    1/1/2016 21:17  1/2/2016 1:37   1/2/2016 20:38  1/5/2016 17:45
# CATEGORY*          Business       Business         Business        Business
# START*          Fort Pierce    Fort Pierce      Fort Pierce     Fort Pierce
# STOP*           Fort Pierce    Fort Pierce      Fort Pierce     Fort Pierce
# MILES*                  5.1              5              4.8             4.7
# PURPOSE*     Meal/Entertain            NaN  Errand/Supplies         Meeting
#
#                         4                5                6     \
# START_DATE*   1/6/2016 14:42   1/6/2016 17:15   1/6/2016 17:30
# END_DATE*     1/6/2016 15:49   1/6/2016 17:19   1/6/2016 17:35
# CATEGORY*           Business         Business         Business
# START*           Fort Pierce  West Palm Beach  West Palm Beach
# ...

# %%
# data exploration method

# %%
uber_df['CATEGORY*'].unique() # to check the values present in the category column
# Out:
# array(['Business', 'Personal', nan], dtype=object)

# %%
uber_df['CATEGORY*'].nunique()
# Out:
# 2

# %%
uber_df['CATEGORY*'].value_counts() # value counts excludes the null value.
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
uber_df['CATEGORY*'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
uber_df['PURPOSE*'].unique()
# Out:
# array(['Meal/Entertain', nan, 'Errand/Supplies', 'Meeting',
#        'Customer Visit', 'Temporary Site', 'Between Offices',
#        'Charity ($)', 'Commute', 'Moving', 'Airport/Travel'], dtype=object)

# %%
uber_df['PURPOSE*'].nunique()
# Out:
# 10

# %%
uber_df['PURPOSE*'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Commute              1
# Charity ($)          1
# Name: PURPOSE*, dtype: int64

# %%
uber_df['PURPOSE*'].value_counts()[1]
# Out:
# 160

# %%
uber_df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
uber_df_without_last_row = pd.read_csv('UberDrives2016.csv',skipfooter=1,engine = 'python' )

# %%
uber_df_without_last_row.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Kar?chi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Kar?chi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 1145           Kar?chi     2.8  Errand/Supplies
# 1146           Kar?chi     2.9  Errand/Supplies
# 1147           Kar?chi     4.6  Errand/Supplies
# ...

# %% [markdown]
# # Selection / Indexing

# %%
uber_df['START*'] # selecting particular column from the dataframe
# Out:
# 0            Fort Pierce
# 1            Fort Pierce
# 2            Fort Pierce
# 3            Fort Pierce
# 4            Fort Pierce
#               ...
# 1151             Kar?chi
# 1152    Unknown Location
# 1153          Katunayake
# 1154             Gampaha
# 1155                 NaN
# Name: START*, Length: 1156, dtype: object

# %%
uber_df[['START*', 'STOP*']]
# Out:
#                 START*             STOP*
# 0          Fort Pierce       Fort Pierce
# 1          Fort Pierce       Fort Pierce
# 2          Fort Pierce       Fort Pierce
# 3          Fort Pierce       Fort Pierce
# 4          Fort Pierce   West Palm Beach
# ...                ...               ...
# 1151           Kar?chi  Unknown Location
# 1152  Unknown Location  Unknown Location
# 1153        Katunayake           Gampaha
# 1154           Gampaha         Ilukwatta
# 1155               NaN               NaN
#
# [1156 rows x 2 columns]

# %%
uber_df.head(3)
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*        STOP*  MILES*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce  Fort Pierce     5.1
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce  Fort Pierce     5.0
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce  Fort Pierce     4.8
#
#           PURPOSE*
# 0   Meal/Entertain
# 1              NaN
# 2  Errand/Supplies

# %%
uber_df.iloc[0:10,0:3].head(10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*
# 0   1/1/2016 21:11   1/1/2016 21:17  Business
# 1    1/2/2016 1:25    1/2/2016 1:37  Business
# 2   1/2/2016 20:25   1/2/2016 20:38  Business
# 3   1/5/2016 17:31   1/5/2016 17:45  Business
# 4   1/6/2016 14:42   1/6/2016 15:49  Business
# 5   1/6/2016 17:15   1/6/2016 17:19  Business
# 6   1/6/2016 17:30   1/6/2016 17:35  Business
# 7   1/7/2016 13:27   1/7/2016 13:33  Business
# 8   1/10/2016 8:05   1/10/2016 8:25  Business
# 9  1/10/2016 12:17  1/10/2016 12:44  Business

# %%
# label are just names for rows.

# %%
uber_df.loc[0:9,['CATEGORY*','START_DATE*','END_DATE*']]
# Out:
#   CATEGORY*      START_DATE*        END_DATE*
# 0  Business   1/1/2016 21:11   1/1/2016 21:17
# 1  Business    1/2/2016 1:25    1/2/2016 1:37
# 2  Business   1/2/2016 20:25   1/2/2016 20:38
# 3  Business   1/5/2016 17:31   1/5/2016 17:45
# 4  Business   1/6/2016 14:42   1/6/2016 15:49
# 5  Business   1/6/2016 17:15   1/6/2016 17:19
# 6  Business   1/6/2016 17:30   1/6/2016 17:35
# 7  Business   1/7/2016 13:27   1/7/2016 13:33
# 8  Business   1/10/2016 8:05   1/10/2016 8:25
# 9  Business  1/10/2016 12:17  1/10/2016 12:44

# %%
uber_df.iloc[:,[2,6]]
# Out:
#      CATEGORY*         PURPOSE*
# 0     Business   Meal/Entertain
# 1     Business              NaN
# 2     Business  Errand/Supplies
# 3     Business          Meeting
# 4     Business   Customer Visit
# ...        ...              ...
# 1151  Business   Temporary Site
# 1152  Business          Meeting
# 1153  Business   Temporary Site
# 1154  Business   Temporary Site
# 1155       NaN              NaN
#
# [1156 rows x 2 columns]

# %%
# conditional Selection

# %%
uber_df.head(6)
# Out:
#       START_DATE*       END_DATE* CATEGORY*           START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business      Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business      Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit
# 5     4.3   Meal/Entertain

# %%
uber_df[uber_df['MILES*']<10]
# Out:
#            START_DATE*         END_DATE* CATEGORY*           START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business      Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business      Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business      Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business      Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business  West Palm Beach
# ...                ...               ...       ...              ...
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business          Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business          Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business          Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business          Kar?chi
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business       Katunayake
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# 1          Fort Pierce     5.0              NaN
# ...

# %%
uber_df.loc[uber_df['MILES*']<10, ['START*','STOP*']]
# Out:
#                START*             STOP*
# 0         Fort Pierce       Fort Pierce
# 1         Fort Pierce       Fort Pierce
# 2         Fort Pierce       Fort Pierce
# 3         Fort Pierce       Fort Pierce
# 5     West Palm Beach   West Palm Beach
# ...               ...               ...
# 1148          Kar?chi           Kar?chi
# 1149          Kar?chi           Kar?chi
# 1150          Kar?chi           Kar?chi
# 1151          Kar?chi  Unknown Location
# 1153       Katunayake           Gampaha
#
# [837 rows x 2 columns]

# %%
print("The total number of rides in which miles covered is less than or equal to 10 is:")
print(uber_df.loc[uber_df['MILES*']<=10, ['START*','STOP*']].shape[0])
# Out:
# The total number of rides in which miles covered is less than or equal to 10 is:
# 840

# %% [markdown]
# # How to sort the dataframe?

# %%
# sorting the dataframe according to the miles column.

uber_df.sort_values(by = 'MILES*')
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
# 1111   12/25/2016 0:10   12/25/2016 0:14  Business            Lahore
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# ...                ...               ...       ...               ...
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 420            Tribeca      0.5  Errand/Supplies
# ...

# %%
# sorting data in descending order

uber_df.sort_values(by = "MILES*", ascending= False)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# ...                ...               ...       ...               ...
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*
# 1155               NaN  12204.7              NaN
# ...

# %%
# sorting data by multiple columns.

uber_df.sort_values(by = ['START*','MILES*'], ascending=['True','False']).head(25)
# Out:
#            START_DATE*         END_DATE* CATEGORY*                     START*  \
# 908     11/5/2016 8:34    11/5/2016 8:43  Business                      Agnew
# 910    11/5/2016 19:20   11/5/2016 19:28  Business                      Agnew
# 911    11/6/2016 10:50   11/6/2016 11:04  Business                      Agnew
# 906    11/4/2016 21:04   11/4/2016 21:20  Business                      Agnew
# 879   10/30/2016 12:58  10/30/2016 13:18  Business                     Almond
# 646    8/10/2016 18:49   8/10/2016 18:50  Business                       Apex
# 855   10/25/2016 15:04  10/25/2016 15:11  Business                       Apex
# 825   10/17/2016 18:31  10/17/2016 18:45  Business                       Apex
# 616     8/1/2016 15:40    8/1/2016 15:47  Business                       Apex
# 1045  12/12/2016 14:26  12/12/2016 14:39  Business                       Apex
# 826   10/17/2016 19:08  10/17/2016 19:25  Business                       Apex
# ...

# %%
# how to change the datatype of particular column

uber_df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
# changing the start_date column from object type to datetime type

# %%
uber_df['START_DATE*'] = pd.to_datetime(uber_df['START_DATE*'], errors='coerce')

# %%
uber_df.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %% [markdown]
# # Group by

# %%
uber_df.groupby(['START*']).count()# how many rides were taken from each and every start place?
# Out:
#                  START_DATE*  END_DATE*  CATEGORY*  STOP*  MILES*  PURPOSE*
# START*
# Agnew                      4          4          4      4       4         0
# Almond                     1          1          1      1       1         0
# Apex                      17         17         17     17      17        11
# Arabi                      1          1          1      1       1         1
# Arlington                  1          1          1      1       1         0
# ...                      ...        ...        ...    ...     ...       ...
# West University            2          2          2      2       2         1
# Weston                     2          2          2      2       2         1
# Westpark Place            17         17         17     17      17         5
# Whitebridge               68         68         68     68      68        36
# Winston Salem              1          1          1      1       1         1
#
# [177 rows x 6 columns]

# %%
uber_df.groupby('START*')['MILES*'].count()
# Out:
# START*
# Agnew               4
# Almond              1
# Apex               17
# Arabi               1
# Arlington           1
#                    ..
# West University     2
# Weston              2
# Westpark Place     17
# Whitebridge        68
# Winston Salem       1
# Name: MILES*, Length: 177, dtype: int64

# %%
uber_df.groupby('START*')['MILES*'].agg(['mean']) # to find the average miles per start destination.
# Out:
#                        mean
# START*
# Agnew              2.775000
# Almond            15.200000
# Apex               5.341176
# Arabi             17.000000
# Arlington          4.900000
# ...                     ...
# West University    2.200000
# Weston             4.000000
# Westpark Place     2.182353
# Whitebridge        4.020588
# Winston Salem    133.600000
#
# [177 rows x 1 columns]

# %%
uber_df.groupby('START*')['MILES*'].agg(['count','mean','sum','max','min'])
# Out:
#                  count        mean    sum    max    min
# START*
# Agnew                4    2.775000   11.1    4.3    2.2
# Almond               1   15.200000   15.2   15.2   15.2
# Apex                17    5.341176   90.8    9.0    1.0
# Arabi                1   17.000000   17.0   17.0   17.0
# Arlington            1    4.900000    4.9    4.9    4.9
# ...                ...         ...    ...    ...    ...
# West University      2    2.200000    4.4    2.3    2.1
# Weston               2    4.000000    8.0    4.2    3.8
# Westpark Place      17    2.182353   37.1    4.2    1.7
# Whitebridge         68    4.020588  273.4    9.0    0.6
# Winston Salem        1  133.600000  133.6  133.6  133.6
#
# [177 rows x 5 columns]

# %% [markdown]
# # Conditinally adding new column

# %%
import numpy as np

# %%
uber_df['MILES CATEGORY*'] = np.where(uber_df['MILES*']>10, "Long Trip", "Short Trip")

# the first value passed in np.where method is condition to be checked.
# the second  value passed in np.where method is the value to be populated when condition is satisfied
# the third  value passed in np.where method is the value to be populated when condition is not satisfied.

# %%
uber_df
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00    1/1/2016 21:17  Business       Fort Pierce
# 1    2016-01-02 01:25:00     1/2/2016 1:37  Business       Fort Pierce
# 2    2016-01-02 20:25:00    1/2/2016 20:38  Business       Fort Pierce
# 3    2016-01-05 17:31:00    1/5/2016 17:45  Business       Fort Pierce
# 4    2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# ...                  ...               ...       ...               ...
# 1151 2016-12-31 13:24:00  12/31/2016 13:42  Business           Kar?chi
# 1152 2016-12-31 15:03:00  12/31/2016 15:38  Business  Unknown Location
# 1153 2016-12-31 21:32:00  12/31/2016 21:50  Business        Katunayake
# 1154 2016-12-31 22:08:00  12/31/2016 23:51  Business           Gampaha
# 1155                 NaT               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE* MILES CATEGORY*
# ...

# %%
uber_df['MILES CATEGORY*'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
uber_df.groupby(['MILES CATEGORY*']).agg(['count', 'max','min'])
# Out:
#                 START_DATE*                                         MILES*  \
#                       count                 max                 min  count
# MILES CATEGORY*
# Long Trip               315 2016-12-31 22:08:00 2016-01-06 14:42:00    316
# Short Trip              840 2016-12-31 21:32:00 2016-01-01 21:11:00    840
#
#
#                      max   min
# MILES CATEGORY*
# Long Trip        12204.7  10.1
# Short Trip          10.0   0.5

# %% [markdown]
# # Missing values

# %%
# how to detect missing value?uber

# %%
uber_df['START_DATE*'].isnull().mean()
# Out:
# 0.0008650519031141869

# %%
# how to impute null values?

# %%
uber_df['PURPOSE*'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Commute              1
# Charity ($)          1
# Name: PURPOSE*, dtype: int64

# %%
uber_df['PURPOSE*'].fillna('Meeting', inplace= True)

# %%
uber_df.isnull().sum()
# Out:
# START_DATE*        1
# END_DATE*          1
# CATEGORY*          1
# START*             1
# STOP*              1
# MILES*             0
# PURPOSE*           0
# MILES CATEGORY*    0
# dtype: int64

# %%
uber_df.dtypes
# Out:
# START_DATE*        datetime64[ns]
# END_DATE*                  object
# CATEGORY*                  object
# START*                     object
# STOP*                      object
# MILES*                    float64
# PURPOSE*                   object
# MILES CATEGORY*            object
# dtype: object

# %%
uber_df['CATEGORY*'].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
uber_df['CATEGORY*'].fillna('Business', inplace = True)

# %%
uber_df[['START*']].mode()
# Out:
#   START*
# 0   Cary

# %%
uber_df['START*'].fillna('Cary', inplace = True)

# %%
uber_df['STOP*'].fillna('Cary', inplace = True)

# %%
uber_df['END_DATE*'].fillna('6/28/2016 23:59', inplace = True)

# %%
uber_df.isnull().sum()
# Out:
# START_DATE*        1
# END_DATE*          0
# CATEGORY*          0
# START*             0
# STOP*              0
# MILES*             0
# PURPOSE*           0
# MILES CATEGORY*    0
# dtype: int64

# %%
uber_df.dropna(inplace = True)

# %%
uber_df.isnull().sum()
# Out:
# START_DATE*        0
# END_DATE*          0
# CATEGORY*          0
# START*             0
# STOP*              0
# MILES*             0
# PURPOSE*           0
# MILES CATEGORY*    0
# dtype: int64
